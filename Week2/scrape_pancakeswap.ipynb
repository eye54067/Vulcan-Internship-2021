# %% [markdown]
# # Week 2 : Pancakeswap

# %% [markdown]
# ## CoinMarketCap Scraper

# %% [markdown]
# ### Set up

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
pip install cryptocmd
# Out:
# ...
#      |████████████████████████████████| 51kB 3.9MB/s
# ...

# %%
pip install git+git://github.com/guptarohit/cryptoCMD.git
# Out:
# ...
#   Cloning git://github.com/guptarohit/cryptoCMD.git to /tmp/pip-req-build-ng6whxem
#   Running command git clone -q git://github.com/guptarohit/cryptoCMD.git /tmp/pip-req-build-ng6whxem
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for cryptocmd: filename=cryptocmd-0.6.0-cp37-none-any.whl size=8499 sha256=c29daed38fd42a2b409bba9e617ed666b5b62174493d1bc0968343ba6bf424ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tp42fik2/wheels/3b/5f/08/ef25df38c4d2e83e00959c4eb734c7ea2f2074fef3789d8392
# Successfully built cryptocmd

# %% [markdown]
# ###To get all time historical data of a cryptocurrency

# %%
from cryptocmd import CmcScraper

# initialise scraper without time interval
scraper = CmcScraper("CAKE")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
cake_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional `name` parameter
scraper.export("csv", name="cake_all_time")

# Pandas dataFrame for the same data
df = scraper.get_dataframe()

# %%
headers
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']

# %%
scraper
headers
data
cake_json_data
scraper.export("csv", name="cake_all_time")
df
# Out:
#           Date       Open       High  ...      Close        Volume    Market Cap
# 0   2021-06-13  15.720859  17.123544  ...  16.874592  1.577334e+08  3.051177e+09
# 1   2021-06-12  15.957841  16.265633  ...  15.697269  1.626228e+08  2.829467e+09
# 2   2021-06-11  16.767677  17.478569  ...  15.966476  1.822588e+08  2.868953e+09
# 3   2021-06-10  18.441326  18.593867  ...  16.783030  2.346339e+08  3.006176e+09
# 4   2021-06-09  17.000755  18.581747  ...  18.444813  2.674280e+08  3.293458e+09
# ..         ...        ...        ...  ...        ...           ...           ...
# 253 2020-10-03   0.506091   0.721180  ...   0.666428  5.491573e+06  5.310660e+06
# 254 2020-10-02   0.415188   0.551662  ...   0.506049  3.022650e+06  4.032618e+06
# 255 2020-10-01   0.435000   0.538305  ...   0.415366  4.444223e+06  3.309981e+06
# 256 2020-09-30   1.115781   1.115977  ...   0.436443  6.704237e+06  3.477943e+06
# 257 2020-09-29   1.374533   1.374533  ...   1.117862  0.000000e+00  8.908058e+06
#
# ...

# %% [markdown]
# ###To get data of a cryptocurrency for some days

# %%
from cryptocmd import CmcScraper

# initialise scraper with time interval
scraper = CmcScraper("CAKE", "9-6-2019", "9-6-2021")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
json_data = scraper.get_data("json")

# export the data to csv
scraper.export("csv")

# get dataframe for the data
df2 = scraper.get_dataframe()

# %%
scraper
headers
data
json_data
scraper.export("csv")
df2
# Out:
#           Date       Open       High  ...      Close        Volume    Market Cap
# 0   2021-06-09  17.000755  18.581747  ...  18.444813  2.674280e+08  3.293458e+09
# 1   2021-06-08  17.035007  17.487602  ...  17.052660  3.329324e+08  3.035289e+09
# 2   2021-06-07  18.835681  20.357541  ...  16.998371  2.768468e+08  3.110397e+09
# 3   2021-06-06  18.960005  19.475846  ...  18.836655  1.951076e+08  3.364766e+09
# 4   2021-06-05  19.092075  21.044845  ...  18.962774  2.639653e+08  3.376704e+09
# ..         ...        ...        ...  ...        ...           ...           ...
# 249 2020-10-03   0.506091   0.721180  ...   0.666428  5.491573e+06  5.310660e+06
# 250 2020-10-02   0.415188   0.551662  ...   0.506049  3.022650e+06  4.032618e+06
# 251 2020-10-01   0.435000   0.538305  ...   0.415366  4.444223e+06  3.309981e+06
# 252 2020-09-30   1.115781   1.115977  ...   0.436443  6.704237e+06  3.477943e+06
# 253 2020-09-29   1.374533   1.374533  ...   1.117862  0.000000e+00  8.908058e+06
#
# ...

# %% [markdown]
# ## Pancakeswap scraper

# %% [markdown]
# ### โหลด CSV จากลิ้งมาลง Folder ปัจจุบัน

# %% [markdown]
# Cr. Earth

# %%
import requests
import pandas as pd
filename = 'pancakeswap.csv' #ชื่อไฟล์ทีต้องการตั้ง
url = 'http://api.llama.fi/dataset/pancakeswap.csv' #ลิ้งโหลดไฟล์
req = requests.get(url, allow_redirects=True)
csv_content = req.content
csv_file = open(filename,'wb')
csv_file.write(csv_content)
csv_file.close()
#แก้ไฟล์ที่โหลดมาไม่ได้ to_csv ทับแล้วแก้ได้
df = pd.read_csv('pancakeswap.csv')
df.to_csv(filename,index=False)

# %%
filename
url
req
csv_content
csv_file
df
# Out:
#            Date   Timestamp  ...                PYX                RUSD
# 0    18/09/2020  1600466400  ...                  -                   -
# 1    19/09/2020  1600552800  ...                  -                   -
# 2    20/09/2020  1600639200  ...                  -                   -
# 3    21/09/2020  1600725600  ...                  -                   -
# 4    22/09/2020  1600812000  ...                  -                   -
# ..          ...         ...  ...                ...                 ...
# 264  10/06/2021  1623283200  ...                  -                   -
# 265  11/06/2021  1623369600  ...  574505.0320014553  7.5019131187903385
# 266  12/06/2021  1623456000  ...   577399.303080589  7.5019131187903385
# 267  13/06/2021  1623542400  ...   632756.062851685  7.5019131187903385
# 268  14/06/2021  1623628800  ...   651474.746193079  7.5019131187903385
#
# [269 rows x 1557 columns]

# %% [markdown]
# ## Cake emission rate

# %% [markdown]
# ### Data description & preparation

# %%
#R
# %load_ext rpy2.ipython

# %%
# %%R
# library(tidyverse)
# Out:
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# R[write to console]: ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# %%R
# df1 <- read_csv("./jan2021/01-1-2021.csv")
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   Txhash = col_character(),
#   Blockno = col_double(),
#   UnixTimestamp = col_double(),
#   DateTime = col_character(),
#   From = col_character(),
#   To = col_character(),
#   ContractAddress = col_logical(),
#   `Value_IN(BNB)` = col_double(),
#   `Value_OUT(BNB)` = col_double(),
#   `CurrentValue @ $361.53/BNB` = col_double(),
#   `TxnFee(BNB)` = col_double(),
#   `TxnFee(USD)` = col_double(),
#   `Historical $Price/BNB` = col_double(),
#   Status = col_character(),
#   ErrCode = col_character(),
#   PrivateNote = col_logical()
# )

# %%
# %%R
# df1
# Out:
# # A tibble: 3,603 x 16
#    Txhash       Blockno UnixTimestamp DateTime From     To       ContractAddress
#    <chr>          <dbl>         <dbl> <chr>    <chr>    <chr>    <lgl>
#  1 0xcfe5bf52c… 3593329    1609459235 1/1/202… 0x40e89… 0x0e09f… NA
#  2 0xb98599640… 3593333    1609459247 1/1/202… 0xb8cce… 0x0e09f… NA
#  3 0x42a472067… 3593336    1609459256 1/1/202… 0x40e89… 0x0e09f… NA
#  4 0x37570990b… 3593350    1609459298 1/1/202… 0x8b742… 0x0e09f… NA
#  5 0xdb4f66961… 3593368    1609459352 1/1/202… 0x22305… 0x0e09f… NA
#  6 0x7e52fc7ea… 3593373    1609459367 1/1/202… 0x22305… 0x0e09f… NA
#  7 0x880076231… 3593382    1609459394 1/1/202… 0x057f3… 0x0e09f… NA
#  8 0x71e4d4619… 3593412    1609459484 1/1/202… 0x631fc… 0x0e09f… NA
#  9 0x081475f17… 3593414    1609459490 1/1/202… 0x50df7… 0x0e09f… NA
# 10 0xcb43a4d31… 3593425    1609459523 1/1/202… 0x718e5… 0x0e09f… NA
# # … with 3,593 more rows, and 9 more variables: Value_IN(BNB) <dbl>,
# ...
